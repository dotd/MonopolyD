# %%
import numpy as np

rnd = np.random.RandomState(1)

class Square():
    
    typs = ['money_change', 'asset']
    
    def __init__(self):
        self.type = Square.typs[rnd.randint(len(Square.typs))]
        self.owner = None
        if self.type=="asset":
            self.price_ladder = rnd.randint(1,10) * np.array(list(range(100,600,100)))
            self.ownership_level = 0
        elif self.type=="money_change":
            self.money_change = rnd.randint(-100,100)
            
    def tostr(self):
        sb = "type={} ".format(self.type)
        if self.type=="asset":
            sb += "owner={} ".format(self.owner)
            sb += ",".join(str(x) for x in self.price_ladder)
        else:
            sb += "money_change={}".format(self.money_change)
        return sb

class MonopolyD():
    
    def __init__(self, num_squares=40, num_players=4, money_start = 1500):
        self.num_squares = num_squares
        self.num_players = num_players
        self.position = [0] * num_players
        self.money = [money_start] * num_players
        self.min_advance = 1
        self.max_advance = 3
        self.cur_player = 0
        self.squares = []
        for i in range(self.num_squares):
            self.squares.append(Square())
        self.rounds = 100

    actions = ["nothing", "buy"]
        
    def run(self):
        for self.round in range(self.rounds):
            print("---------------")
            print("Board")
            print(self.show_board())
            print("Before:\n" + self.__str__())

            # Advance the player on the board
            self.advance(self.cur_player)
            
            player_square = self.squares[self.position[self.cur_player]]
            actions = self.get_actions(self.cur_player, player_square)
            print(">> Possible actions: " + self.show_actions(actions))
            # random action
            action_idx = rnd.choice(len(actions))
            action = actions[action_idx]
            print(">> Chosen action: " + str(action))
            self.apply_pays(self.cur_player, player_square, action)
            
            print(">> After:\n" + self.__str__())

            self.next_player()
            
    def next_player(self):
        self.cur_player = (self.cur_player + 1) % self.num_players
        
    def advance(self,player):
        self.position[player] = (self.position[player] + rnd.randint(self.min_advance,self.max_advance)) % self.num_squares
    
    def __str__(self, lines_seperator="\n"):
        s = []
        s.append("round={}".format(self.round))
        s.append("player={}, players are in {}".format(self.cur_player, ",".join([str(x) for x in self.position]) ) )
        s.append("money status: " + str(self.money))
        return lines_seperator.join(s)
    
    def show_board(self, lines_seperator="\n"):
        s = []
        s.append(lines_seperator.join(x.tostr() for x in self.squares))
        return lines_seperator.join(s)
        
    actions = ["nothing", "buy"]

    def show_actions(self, actions, separator="; "):
        s = []
        for action,cost in actions:
            s.append("{}->{} ".format(action, cost))
        return separator.join(s)
    
    def get_actions(self, player, square):
        if square.type=="asset" and square.owner==None:
            actions = [("nothing",0), ("buy",square.price_ladder[0])]
        elif square.type=="asset" and square.owner==player and square.ownership_level<len(square.price_ladder)-1:
            actions = [("nothing",0), ("buy",square.price_ladder[square.ownership_level+1])]
        else:
            actions = [("nothing",0)]
        return actions
        
    def apply_pays(self, player, square, action):
        if (square.type=="asset") and (square.owner ==None) and (square.owner!=player) and action[0]=="buy" and self.money[player] >= action[1]:
            diff = -square.price_ladder[square.ownership_level]
            self.money[player] += diff
        elif square.type=="money_change":
            self.money[player] += square.money_change
        else:
            print("apply_pays did nothing")
        
    
        
m = MonopolyD(num_squares=6, num_players=2)
m.run()
# Out:
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=0
# player=0, players are in 0,0
# money status: [1500, 1500]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=0
# player=0, players are in 2,0
# money status: [1500, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=1
# player=1, players are in 2,0
# money status: [1500, 1500]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=1
# player=1, players are in 2,1
# money status: [1500, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=2
# player=0, players are in 2,1
# money status: [1500, 1500]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=2
# player=0, players are in 4,1
# money status: [1471, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=3
# player=1, players are in 4,1
# money status: [1471, 1500]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=3
# player=1, players are in 4,2
# money status: [1471, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=4
# player=0, players are in 4,2
# money status: [1471, 1500]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=4
# player=0, players are in 0,2
# money status: [1471, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=5
# player=1, players are in 0,2
# money status: [1471, 1500]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=5
# player=1, players are in 0,3
# money status: [1471, 1529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=6
# player=0, players are in 0,3
# money status: [1471, 1529]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# >> After:
# round=6
# player=0, players are in 1,3
# money status: [871, 1529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=7
# player=1, players are in 1,3
# money status: [871, 1529]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=7
# player=1, players are in 1,4
# money status: [871, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=8
# player=0, players are in 1,4
# money status: [871, 1500]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=8
# player=0, players are in 2,4
# money status: [871, 1500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=9
# player=1, players are in 2,4
# money status: [871, 1500]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# >> After:
# round=9
# player=1, players are in 2,0
# money status: [871, 600]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=10
# player=0, players are in 2,0
# money status: [871, 600]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=10
# player=0, players are in 4,0
# money status: [842, 600]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=11
# player=1, players are in 4,0
# money status: [842, 600]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('buy', 100)
# >> After:
# round=11
# player=1, players are in 4,2
# money status: [842, 500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=12
# player=0, players are in 4,2
# money status: [842, 500]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=12
# player=0, players are in 5,2
# money status: [842, 500]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=13
# player=1, players are in 5,2
# money status: [842, 500]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=13
# player=1, players are in 5,3
# money status: [842, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=14
# player=0, players are in 5,3
# money status: [842, 529]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# >> After:
# round=14
# player=0, players are in 1,3
# money status: [242, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=15
# player=1, players are in 1,3
# money status: [242, 529]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=15
# player=1, players are in 1,5
# money status: [242, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=16
# player=0, players are in 1,5
# money status: [242, 529]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=16
# player=0, players are in 3,5
# money status: [271, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=17
# player=1, players are in 3,5
# money status: [271, 529]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=17
# player=1, players are in 3,1
# money status: [271, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=18
# player=0, players are in 3,1
# money status: [271, 529]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=18
# player=0, players are in 5,1
# money status: [271, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=19
# player=1, players are in 5,1
# money status: [271, 529]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=19
# player=1, players are in 5,2
# money status: [271, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=20
# player=0, players are in 5,2
# money status: [271, 529]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=20
# player=0, players are in 1,2
# money status: [271, 529]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=21
# player=1, players are in 1,2
# money status: [271, 529]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=21
# player=1, players are in 1,3
# money status: [271, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=22
# player=0, players are in 1,3
# money status: [271, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=22
# player=0, players are in 3,3
# money status: [300, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=23
# player=1, players are in 3,3
# money status: [300, 558]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=23
# player=1, players are in 3,5
# money status: [300, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=24
# player=0, players are in 3,5
# money status: [300, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=24
# player=0, players are in 4,5
# money status: [271, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=25
# player=1, players are in 4,5
# money status: [271, 558]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=25
# player=1, players are in 4,1
# money status: [271, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=26
# player=0, players are in 4,1
# money status: [271, 558]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=26
# player=0, players are in 5,1
# money status: [271, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=27
# player=1, players are in 5,1
# money status: [271, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=27
# player=1, players are in 5,3
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=28
# player=0, players are in 5,3
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=28
# player=0, players are in 0,3
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=29
# player=1, players are in 0,3
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=29
# player=1, players are in 0,5
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=30
# player=0, players are in 0,5
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=30
# player=0, players are in 2,5
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=31
# player=1, players are in 2,5
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=31
# player=1, players are in 2,0
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=32
# player=0, players are in 2,0
# money status: [271, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=32
# player=0, players are in 4,0
# money status: [242, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=33
# player=1, players are in 4,0
# money status: [242, 587]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=33
# player=1, players are in 4,1
# money status: [242, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=34
# player=0, players are in 4,1
# money status: [242, 587]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=34
# player=0, players are in 5,1
# money status: [242, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=35
# player=1, players are in 5,1
# money status: [242, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=35
# player=1, players are in 5,3
# money status: [242, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=36
# player=0, players are in 5,3
# money status: [242, 616]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# apply_pays did nothing
# >> After:
# round=36
# player=0, players are in 1,3
# money status: [242, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=37
# player=1, players are in 1,3
# money status: [242, 616]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=37
# player=1, players are in 1,4
# money status: [242, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=38
# player=0, players are in 1,4
# money status: [242, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=38
# player=0, players are in 3,4
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=39
# player=1, players are in 3,4
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=39
# player=1, players are in 3,5
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=40
# player=0, players are in 3,5
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=40
# player=0, players are in 5,5
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=41
# player=1, players are in 5,5
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=41
# player=1, players are in 5,0
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=42
# player=0, players are in 5,0
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=42
# player=0, players are in 1,0
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=43
# player=1, players are in 1,0
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=43
# player=1, players are in 1,2
# money status: [271, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=44
# player=0, players are in 1,2
# money status: [271, 587]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('buy', 100)
# >> After:
# round=44
# player=0, players are in 2,2
# money status: [171, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=45
# player=1, players are in 2,2
# money status: [171, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=45
# player=1, players are in 2,4
# money status: [171, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=46
# player=0, players are in 2,4
# money status: [171, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=46
# player=0, players are in 4,4
# money status: [142, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=47
# player=1, players are in 4,4
# money status: [142, 558]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=47
# player=1, players are in 4,5
# money status: [142, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=48
# player=0, players are in 4,5
# money status: [142, 558]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=48
# player=0, players are in 0,5
# money status: [142, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=49
# player=1, players are in 0,5
# money status: [142, 558]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# apply_pays did nothing
# >> After:
# round=49
# player=1, players are in 0,1
# money status: [142, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=50
# player=0, players are in 0,1
# money status: [142, 558]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('buy', 100)
# >> After:
# round=50
# player=0, players are in 2,1
# money status: [42, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=51
# player=1, players are in 2,1
# money status: [42, 558]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=51
# player=1, players are in 2,2
# money status: [42, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=52
# player=0, players are in 2,2
# money status: [42, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=52
# player=0, players are in 3,2
# money status: [71, 558]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=53
# player=1, players are in 3,2
# money status: [71, 558]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=53
# player=1, players are in 3,3
# money status: [71, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=54
# player=0, players are in 3,3
# money status: [71, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=54
# player=0, players are in 4,3
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=55
# player=1, players are in 4,3
# money status: [42, 587]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=55
# player=1, players are in 4,5
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=56
# player=0, players are in 4,5
# money status: [42, 587]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=56
# player=0, players are in 0,5
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=57
# player=1, players are in 0,5
# money status: [42, 587]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# apply_pays did nothing
# >> After:
# round=57
# player=1, players are in 0,1
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=58
# player=0, players are in 0,1
# money status: [42, 587]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=58
# player=0, players are in 2,1
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=59
# player=1, players are in 2,1
# money status: [42, 587]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=59
# player=1, players are in 2,2
# money status: [42, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=60
# player=0, players are in 2,2
# money status: [42, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=60
# player=0, players are in 3,2
# money status: [71, 587]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=61
# player=1, players are in 3,2
# money status: [71, 587]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=61
# player=1, players are in 3,3
# money status: [71, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=62
# player=0, players are in 3,3
# money status: [71, 616]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=62
# player=0, players are in 4,3
# money status: [42, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=63
# player=1, players are in 4,3
# money status: [42, 616]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=63
# player=1, players are in 4,5
# money status: [42, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=64
# player=0, players are in 4,5
# money status: [42, 616]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=64
# player=0, players are in 0,5
# money status: [42, 616]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=65
# player=1, players are in 0,5
# money status: [42, 616]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# >> After:
# round=65
# player=1, players are in 0,1
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=66
# player=0, players are in 0,1
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=66
# player=0, players are in 1,1
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=67
# player=1, players are in 1,1
# money status: [42, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=67
# player=1, players are in 1,3
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=68
# player=0, players are in 1,3
# money status: [42, 45]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=68
# player=0, players are in 3,3
# money status: [71, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=69
# player=1, players are in 3,3
# money status: [71, 45]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=69
# player=1, players are in 3,4
# money status: [71, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=70
# player=0, players are in 3,4
# money status: [71, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=70
# player=0, players are in 4,4
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=71
# player=1, players are in 4,4
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=71
# player=1, players are in 4,0
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=72
# player=0, players are in 4,0
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=72
# player=0, players are in 5,0
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=73
# player=1, players are in 5,0
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('buy', 100)
# apply_pays did nothing
# >> After:
# round=73
# player=1, players are in 5,2
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=74
# player=0, players are in 5,2
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('buy', 600)
# apply_pays did nothing
# >> After:
# round=74
# player=0, players are in 1,2
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=75
# player=1, players are in 1,2
# money status: [42, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=75
# player=1, players are in 1,4
# money status: [42, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=76
# player=0, players are in 1,4
# money status: [42, -13]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('buy', 100)
# apply_pays did nothing
# >> After:
# round=76
# player=0, players are in 2,4
# money status: [42, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=77
# player=1, players are in 2,4
# money status: [42, -13]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=77
# player=1, players are in 2,5
# money status: [42, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=78
# player=0, players are in 2,5
# money status: [42, -13]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=78
# player=0, players are in 3,5
# money status: [71, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=79
# player=1, players are in 3,5
# money status: [71, -13]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=79
# player=1, players are in 3,0
# money status: [71, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=80
# player=0, players are in 3,0
# money status: [71, -13]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=80
# player=0, players are in 5,0
# money status: [71, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=81
# player=1, players are in 5,0
# money status: [71, -13]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=81
# player=1, players are in 5,2
# money status: [71, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=82
# player=0, players are in 5,2
# money status: [71, -13]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=82
# player=0, players are in 1,2
# money status: [71, -13]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=83
# player=1, players are in 1,2
# money status: [71, -13]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=83
# player=1, players are in 1,3
# money status: [71, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=84
# player=0, players are in 1,3
# money status: [71, 16]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=84
# player=0, players are in 2,3
# money status: [71, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=85
# player=1, players are in 2,3
# money status: [71, 16]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=85
# player=1, players are in 2,5
# money status: [71, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=86
# player=0, players are in 2,5
# money status: [71, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=86
# player=0, players are in 4,5
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=87
# player=1, players are in 4,5
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=87
# player=1, players are in 4,0
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=88
# player=0, players are in 4,0
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('buy', 900)
# apply_pays did nothing
# >> After:
# round=88
# player=0, players are in 0,0
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=89
# player=1, players are in 0,0
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=89
# player=1, players are in 0,1
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=90
# player=0, players are in 0,1
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=90
# player=0, players are in 1,1
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=91
# player=1, players are in 1,1
# money status: [42, 16]
# >> Possible actions: nothing->0 ; buy->100
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=91
# player=1, players are in 1,2
# money status: [42, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=92
# player=0, players are in 1,2
# money status: [42, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=92
# player=0, players are in 3,2
# money status: [71, 16]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=93
# player=1, players are in 3,2
# money status: [71, 16]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=93
# player=1, players are in 3,3
# money status: [71, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=94
# player=0, players are in 3,3
# money status: [71, 45]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=94
# player=0, players are in 4,3
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=95
# player=1, players are in 4,3
# money status: [42, 45]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=95
# player=1, players are in 4,5
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=96
# player=0, players are in 4,5
# money status: [42, 45]
# >> Possible actions: nothing->0 ; buy->700
# >> Chosen action: ('buy', 700)
# apply_pays did nothing
# >> After:
# round=96
# player=0, players are in 5,5
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=97
# player=1, players are in 5,5
# money status: [42, 45]
# >> Possible actions: nothing->0 ; buy->600
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=97
# player=1, players are in 5,1
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=98
# player=0, players are in 5,1
# money status: [42, 45]
# >> Possible actions: nothing->0 ; buy->900
# >> Chosen action: ('nothing', 0)
# apply_pays did nothing
# >> After:
# round=98
# player=0, players are in 0,1
# money status: [42, 45]
# ---------------
# Board
# type=asset owner=None 900,1800,2700,3600,4500
# type=asset owner=None 600,1200,1800,2400,3000
# type=asset owner=None 100,200,300,400,500
# type=money_change money_change=29
# type=money_change money_change=-29
# type=asset owner=None 700,1400,2100,2800,3500
# Before:
# round=99
# player=1, players are in 0,1
# money status: [42, 45]
# >> Possible actions: nothing->0
# >> Chosen action: ('nothing', 0)
# >> After:
# round=99
# player=1, players are in 0,3
# money status: [42, 74]
